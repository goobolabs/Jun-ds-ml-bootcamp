# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
print("import succesfull")
# Out:
# import succesfull

# %%
df= pd.read_csv("clean_car_dataset.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  Size_sqft  Bedrooms  Bathrooms  YearBuilt   Price  \
# 0           0   1.030308 -1.463643   0.088986  -1.279342  812100
# 1           1  -0.482438 -1.463643   1.347506   1.326476  547000
# 2           2   0.468903  0.007430  -1.169534  -1.339942  693700
# 3           3   1.079844  0.742966   1.347506  -0.915740  848300
# 4           4   0.788980  1.478502  -1.169534   0.962873  806000
# 5           5   0.881701  0.007430  -1.169534  -1.339942  724400
# 6           6   1.280527  1.478502   0.088986  -0.612737  715100
# 7           7  -0.266513  0.742966  -1.169534  -0.733938  547900
# 8           8  -0.802515 -0.728107   0.088986  -1.339942  516700
# 9           9  -1.263579  0.742966   1.347506  -1.036940  418600
#
#    Location_City  Location_Rural  Location_Suburb  HouseAge  \
# 0              1               0                0  1.279342
# 1              1               0                0 -1.326476
# 2              1               0                0  1.339942
# 3              1               0                0  0.915740
# 4              0               0                1 -0.962873
# 5              1               0                0  1.339942
# 6              0               0                1  0.612737
# 7              0               0                1  0.733938
# 8              0               0                1  1.339942
# 9              1               0                0  1.036940
#
#    Rooms_Per_1000sqft  Size_per_Bedrooms  Is_City  Log_Price
# 0           -1.061479           3.123142        1  13.607379
# 1           -0.265649           1.309553        1  13.212204
# 2           -0.689560          -0.163957        1  13.449795
# 3           -0.199124          -0.307602        1  13.650990
# 4           -0.311015          -0.610020        0  13.599839
# 5           -0.805379           0.001007        1  13.493099
# 6           -0.274038          -0.492159        0  13.480178
# 7           -0.056463          -0.711130        0  13.213848
# 8           -0.032322          -0.272579        0  13.155218
# 9            2.122585          -1.009969        1  12.944671

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          99 non-null     int64
#  1   Size_sqft           99 non-null     float64
#  2   Bedrooms            99 non-null     float64
#  3   Bathrooms           99 non-null     float64
#  4   YearBuilt           99 non-null     float64
#  5   Price               99 non-null     int64
#  6   Location_City       99 non-null     int64
#  7   Location_Rural      99 non-null     int64
#  8   Location_Suburb     99 non-null     int64
#  9   HouseAge            99 non-null     float64
#  10  Rooms_Per_1000sqft  99 non-null     float64
#  11  Size_per_Bedrooms   99 non-null     float64
#  12  Is_City             99 non-null     int64
#  13  Log_Price           99 non-null     float64
# dtypes: float64(8), int64(6)
# memory usage: 11.0 KB

# %%
df.shape
# Out:
# (99, 14)

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# Size_sqft             0
# Bedrooms              0
# Bathrooms             0
# YearBuilt             0
# Price                 0
# Location_City         0
# Location_Rural        0
# Location_Suburb       0
# HouseAge              0
# Rooms_Per_1000sqft    0
# Size_per_Bedrooms     0
# Is_City               0
# Log_Price             0
# dtype: int64

# %%
x=df.drop("Price",axis=1)
y=df["Price"]

# %%
X_train,X_test,y_train,y_test= train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)

# %%
print(f"Mean Asbsolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R2 Score : {r2}")
# Out:
# Mean Asbsolute Error: 27240.404297779547
# Mean Squared Error: 1219003450.3035982
# R2 Score : 0.9675683912220865
